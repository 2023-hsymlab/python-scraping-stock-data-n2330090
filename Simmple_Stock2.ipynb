# %%
from pandas_datareader import data
start = '2022-04-01'
end = '2023-05-31'
#9984:ソフトバンク
#df = data.DataReader('9984.JP', 'stooq', start, end)
#7832:バンナム
symbols=["9020.JP","9021.JP","9022.JP"]
colors=["red","orange","blue"]
df = data.DataReader(symbols, 'stooq', start, end)
df["Close"].plot(figsize=(20,10),color=colors)
# Out:
# <Axes: xlabel='Date'>
